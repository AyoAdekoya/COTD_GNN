# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# %%
# read from csv file
data = np.genfromtxt('data.csv', delimiter=',', skip_header=1, usecols=(0, 1))
print(data[:5])
# Out:
# [[38.37599755 99.89600857]
#  [23.39722206 49.07771949]
#  [70.83061611 87.56491555]
#  [15.19057318 63.6229945 ]
#  [72.69384271 18.36477946]]

# %%
# run k-means algorithm
k_means = KMeans(n_clusters=3)
k_means.fit(data)

labels = k_means.labels_
centers = k_means.cluster_centers_

# %%
# plot
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x')  # cluster centers
plt.title('K-Means Clustering')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
